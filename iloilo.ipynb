# %%
list_name = []
list_region = []
list_country = []     
list_longitude = []
list_latitude = []
list_time = []# YYYY-MM-DD HH:MM 
list_temp_c = []
list_is_day = []
list_condition = []
list_air_pressure = [] # hPa
list_relative_humidity = [] # relative humidity in percent
list_precipitation = [] # precipitation in mm
list_wind_kph = [] # wind speed in km/h
list_wind_degree = [] # 0-360
list_wind_dir = [] # N, NE, E, SE, S, SW, W, NW
list_cloud = [] # cloudiness in percent
list_feelslike_c = [] # feels like temperature in degrees C
list_will_it_rain = []
list_chance_of_rain = []

# %%
import arrow
import requests
import json
import pandas as pd

stormglass_api = '51336722-4f14-11ec-b247-0242ac130002-513367c2-4f14-11ec-b247-0242ac130002'
weatherapi_key = '995333b3c1334b7da0104356212711'

date = '2022-02-25'
start = arrow.get(date)
q = '10.7, 122.56'
lat = 10.7
lng = 122.56
params = [
    'humidity',
    'precipitation', 
    'pressure',
]

weather_response = requests.get(
    'https://api.weatherapi.com/v1/history.json',
    params={
        'key': weatherapi_key,
        'q': q,
        'dt': date,
    },
)

response = requests.get(
    'https://api.stormglass.io/v2/weather/point',
    params={
        'lat': lat,
        'lng': lng,
        'params': ','.join(params), 
        'start': start.to('Asia/Manila').timestamp(), # convert to UTC
        'end': start.shift(hours=23).to('Asia/Manila').timestamp(),
    },
    headers={
        'Authorization': stormglass_api
    }
)

history_weather_data = weather_response.json()['forecast']['forecastday'][0]['hour']
stormglass_data = response.json()['hours']

for i in stormglass_data:
    humidity = i['humidity']['noaa']
    precipitation = i ['precipitation']['noaa']
    pressure = i['pressure']['noaa']
    list_relative_humidity.append(humidity)
    list_precipitation.append(precipitation)
    list_air_pressure.append(pressure)

for i in history_weather_data:
    name = "Iloilo"
    region = name + " City"
    country = "Philippines"
    longitude = lng
    latitude = lat
    time = i['time']
    temp_c = i['temp_c']
    is_day = i['is_day']
    condition = i['condition']['text']
    wind_kph = i['wind_kph']
    wind_degree = i['wind_degree']
    wind_dir = i['wind_dir']
    cloud = i['cloud']
    feelslike_c = i['feelslike_c']
    will_it_rain = i['will_it_rain']
    chance_of_rain = i['chance_of_rain']
    list_name.append(name)
    list_region.append(region)
    list_country.append(country)
    list_longitude.append(longitude)
    list_latitude.append(latitude)
    list_time.append(time)
    list_temp_c.append(temp_c)
    list_is_day.append(is_day)
    list_condition.append(condition)
    list_wind_kph.append(wind_kph)
    list_wind_degree.append(wind_degree)
    list_wind_dir.append(wind_dir)
    list_cloud.append(cloud)
    list_feelslike_c.append(feelslike_c)
    list_chance_of_rain.append(chance_of_rain)
    list_will_it_rain.append(will_it_rain)

# %%
data = {
    'name': list_name,
    'region': list_region,
    'country': list_country,
    'longitude': list_longitude,
    'latitude': list_latitude,
    'time': list_time,
    'temp_c': list_temp_c,
    'is_day': list_is_day,
    'condition': list_condition,
    'wind_kph': list_wind_kph,
    'wind_degree': list_wind_degree,
    'wind_dir': list_wind_dir,
    'air_pressure': list_air_pressure,
    'precipitation': list_precipitation,
    'relative_humidity': list_relative_humidity,
    'cloud': list_cloud,
    'feelslike_c': list_feelslike_c,
    'will_it_rain': list_will_it_rain,
    'chance_of_rain': list_chance_of_rain,
}
df = pd.DataFrame(data=data)

df.tail()
# Out:
#        name       region      country  longitude  latitude              time  \
# 139  Iloilo  Iloilo City  Philippines     122.56      10.7  2022-02-25 19:00
# 140  Iloilo  Iloilo City  Philippines     122.56      10.7  2022-02-25 20:00
# 141  Iloilo  Iloilo City  Philippines     122.56      10.7  2022-02-25 21:00
# 142  Iloilo  Iloilo City  Philippines     122.56      10.7  2022-02-25 22:00
# 143  Iloilo  Iloilo City  Philippines     122.56      10.7  2022-02-25 23:00
#
#      temp_c  is_day      condition  wind_kph  wind_degree wind_dir  \
# 139    26.9       0  Partly cloudy      28.2           28      NNE
# 140    26.5       0  Partly cloudy      28.7           28      NNE
# 141    26.2       0  Partly cloudy      29.2           28      NNE
# 142    25.9       0  Partly cloudy      28.2           29      NNE
# 143    25.6       0         Cloudy      27.2           29      NNE
#
#      air_pressure  precipitation  relative_humidity  cloud  feelslike_c  \
# 139       1011.25           0.01               82.6     43         29.4
# 140       1011.20           0.01               82.6     39         29.1
# 141       1011.16           0.01               82.6     35         28.7
# 142       1011.76           0.01               80.8     51         28.3
# 143       1012.37           0.01               79.0     67         27.9
#
#      will_it_rain  chance_of_rain
# 139             0               1
# 140             0               1
# 141             0               0
# 142             0               1
# 143             0               2

# %%
df.head()
# Out:
#      name       region      country  longitude  latitude              time  \
# 0  Iloilo  Iloilo City  Philippines     122.56      10.7  2022-02-20 00:00
# 1  Iloilo  Iloilo City  Philippines     122.56      10.7  2022-02-20 01:00
# 2  Iloilo  Iloilo City  Philippines     122.56      10.7  2022-02-20 02:00
# 3  Iloilo  Iloilo City  Philippines     122.56      10.7  2022-02-20 03:00
# 4  Iloilo  Iloilo City  Philippines     122.56      10.7  2022-02-20 04:00
#
#    temp_c  is_day condition  wind_kph  wind_degree wind_dir  air_pressure  \
# 0    25.8       0     Clear      16.6           10        N       1010.38
# 1    25.7       0     Clear      16.6           13      NNE       1010.22
# 2    25.5       0     Clear      16.6           15      NNE       1010.06
# 3    25.4       0     Clear      16.6           17      NNE       1009.89
# 4    25.2       0     Clear      16.6           17      NNE       1008.97
#
#    precipitation  relative_humidity  cloud  feelslike_c  will_it_rain  \
# 0            0.0              79.20      9         28.4             0
# 1            0.0              73.67     10         28.2             0
# 2            0.0              68.13     12         28.0             0
# 3            0.0              62.60     14         27.8             0
# 4            0.0              59.87     20         27.6             0
#
#    chance_of_rain
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
df.to_csv('iloilo-2022-02-2025.csv', index=False)
